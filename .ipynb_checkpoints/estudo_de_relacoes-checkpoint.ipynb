# %%
'''
    Titulo: Como a mobilidade urbana se relaciona com o aumento de numero de casos de covid.


'''


import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %matplotlib notebook

# %%
# path = os.path.dirname(os.path.abspath(__file__))


'''
    Peguei essa primeira parte desse site: https://www.viralml.com/video-content.html?v=A6nWZKZpL3k
'''
# Se demorar mto pra carregar o csv, baixa o csv e descomenta essa linha (ps: ta com o \\ do windows)
# gmr_df = pd.read_csv(path+'\\Global_Mobility_Report.csv')  
gmr_df = pd.read_csv('https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv')
gmr_df.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#   metro_area iso_3166_2_code  census_fips_code                     place_id  \
# 0        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 1        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 2        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 3        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 4        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# 0  2020-02-15                                                0.0
# 1  2020-02-16                                                1.0
# 2  2020-02-17                                               -1.0
# 3  2020-02-18                                               -2.0
# 4  2020-02-19                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
# 3                                                1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
# 3                                 5.0
# 4                                 4.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            0.0
# 1                                            1.0
# 2                                            1.0
# 3                                            0.0
# 4                                           -1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      2.0
# 2                                      2.0
# 3                                      2.0
# 4                                      2.0
#
#    residential_percent_change_from_baseline
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0

# %%
# Categories available
categories_google_mobility = ['retail_and_recreation_percent_change_from_baseline',
 'grocery_and_pharmacy_percent_change_from_baseline',
 'parks_percent_change_from_baseline',
 'transit_stations_percent_change_from_baseline',
 'workplaces_percent_change_from_baseline',
 'residential_percent_change_from_baseline']
categories_google_mobility

regions_list_BR = [ 'Federal District', ' State of Acre,State of Alagoas,State of Amapá', 'State of Amazonas', 
                    'State of Bahia', 'State of Ceará', 'State of Espírito Santo', 'State of Goiás',
                    'State of Maranhão', 'State of Mato Grosso', 'State of Mato Grosso do Sul', 'State of Minas Gerais',
                    'State of Pará', 'State of Paraíba', 'State of Paraná', 'State of Pernambuco', 'State of Piauí', 
                    'State of Rio de Janeiro', 'State of Rio Grande do Norte',
                    'State of Rio Grande do Sul', 'State of Rondônia', 'State of Roraima', 'State of Santa Catarina', 
                    'State of São Paulo', 'State of Sergipe', 'State of Tocantins'
                  ]

# %%
def getAllRegionsGroups(regions_list=regions_list_BR, country="Brazil"):
    regions_dict = {}
#     print(regions_list)
    for r in regions_list:
        sub_df = gmr_df[(gmr_df['country_region']== country) & (gmr_df['sub_region_1']==r) & (pd.isnull(gmr_df['sub_region_2']))]
        sub_df.loc[:,'date'] = pd.to_datetime(sub_df.loc[:,'date'])
        sub_df = sub_df.sort_values('date', ascending=True)
        regions_dict[r]=sub_df
#     print(regions_dict)
    return regions_dict


def plotGroups(sub_df, region, country="Brazil"):
    # let's plot all time series for this region
    for group in categories_google_mobility:
#         print(group)
        
        fig, ax = plt.subplots(figsize=(16, 4))
        plt.plot(sub_df['date'], sub_df[group], label=group)
        ax.axhline(y=0, color='gray')
        ax.axvline(pd.to_datetime('2020-03-10'), color='r', linestyle='--', lw=2)
        plt.title(country + ' '+ region + ': ' + group)
        plt.legend(loc='best') 
        plt.grid()
        plt.show()
        # plt.savefig(fname=path+'\\'+group+'.png', format='png')


# - - - - - - - -  TESTE - - - - - - - -  
sdf = getAllRegionsGroups(regions_list=['State of São Paulo'])   #, 'State of Rio de Janeiro'
print(sdf)
plotGroups(sdf['State of São Paulo'], 'State of São Paulo')
# plotGroups(sdf['State of Rio de Janeiro'], 'State of RIO')
# Out:
# {'State of São Paulo':         country_region_code country_region        sub_region_1 sub_region_2  \
# 1319215                  BR         Brazil  State of São Paulo          NaN
# 1319216                  BR         Brazil  State of São Paulo          NaN
# 1319217                  BR         Brazil  State of São Paulo          NaN
# 1319218                  BR         Brazil  State of São Paulo          NaN
# 1319219                  BR         Brazil  State of São Paulo          NaN
# ...                     ...            ...                 ...          ...
# 1319722                  BR         Brazil  State of São Paulo          NaN
# 1319723                  BR         Brazil  State of São Paulo          NaN
# 1319724                  BR         Brazil  State of São Paulo          NaN
# 1319725                  BR         Brazil  State of São Paulo          NaN
# 1319726                  BR         Brazil  State of São Paulo          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 1319215        NaN           BR-SP               NaN
# 1319216        NaN           BR-SP               NaN
# 1319217        NaN           BR-SP               NaN
# 1319218        NaN           BR-SP               NaN
# 1319219        NaN           BR-SP               NaN
# ...            ...             ...               ...
# 1319722        NaN           BR-SP               NaN
# 1319723        NaN           BR-SP               NaN
# 1319724        NaN           BR-SP               NaN
# 1319725        NaN           BR-SP               NaN
# 1319726        NaN           BR-SP               NaN
#
#                             place_id       date  \
# 1319215  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2020-02-15
# 1319216  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2020-02-16
# 1319217  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2020-02-17
# 1319218  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2020-02-18
# 1319219  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2020-02-19
# ...                              ...        ...
# 1319722  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2021-07-06
# 1319723  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2021-07-07
# 1319724  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2021-07-08
# 1319725  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2021-07-09
# 1319726  ChIJrVgvRn1ZzpQRF3x74eJBUh4 2021-07-10
#
#          retail_and_recreation_percent_change_from_baseline  \
# 1319215                                                6.0
# 1319216                                                7.0
# 1319217                                               -4.0
# 1319218                                               -5.0
# 1319219                                               -3.0
# ...                                                    ...
# 1319722                                              -18.0
# 1319723                                              -13.0
# 1319724                                               -6.0
# 1319725                                              -24.0
# 1319726                                              -14.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 1319215                                                5.0
# 1319216                                                4.0
# 1319217                                               -1.0
# 1319218                                               -3.0
# 1319219                                               -4.0
# ...                                                    ...
# 1319722                                               35.0
# 1319723                                               38.0
# 1319724                                               51.0
# 1319725                                               29.0
# 1319726                                               38.0
#
#          parks_percent_change_from_baseline  \
# 1319215                                 6.0
# 1319216                                 9.0
# 1319217                               -13.0
# 1319218                               -13.0
# 1319219                               -11.0
# ...                                     ...
# 1319722                               -29.0
# 1319723                               -15.0
# 1319724                                 2.0
# 1319725                                 7.0
# 1319726                                 0.0
#
#          transit_stations_percent_change_from_baseline  \
# 1319215                                           11.0
# 1319216                                           10.0
# 1319217                                            8.0
# 1319218                                            9.0
# 1319219                                            8.0
# ...                                                ...
# 1319722                                          -17.0
# 1319723                                          -13.0
# 1319724                                           -8.0
# 1319725                                          -36.0
# 1319726                                          -10.0
#
#          workplaces_percent_change_from_baseline  \
# 1319215                                      8.0
# 1319216                                      1.0
# 1319217                                     18.0
# 1319218                                     14.0
# 1319219                                     14.0
# ...                                          ...
# 1319722                                     -2.0
# 1319723                                     -1.0
# 1319724                                     -1.0
# 1319725                                    -49.0
# 1319726                                      4.0
#
#          residential_percent_change_from_baseline
# 1319215                                      -1.0
# 1319216                                       0.0
# 1319217                                      -1.0
# 1319218                                      -2.0
# 1319219                                      -2.0
# ...                                           ...
# 1319722                                       9.0
# 1319723                                       8.0
# 1319724                                       5.0
# 1319725                                      17.0
# 1319726                                       6.0
#
# [512 rows x 15 columns]}

# %%
# - - - - - - - -  CASOS DE COVID - - - - - - - -  
covid_df = pd.read_csv('https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv')
col = [ 'epi_week', 'date', 'country', 'state', 'city', 'newDeaths', 'deaths', 'newCases', 'totalCases', 
        'deathsMS', 'totalCasesMS', 'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants', 
        'deaths_by_totalCases', 
        'recovered', 'suspects', 'tests', 'tests_per_100k_inhabitants', 'vaccinated', 
        'vaccinated_per_100_inhabitants', 'vaccinated_second', 
        'vaccinated_second_per_100_inhabitants', 'vaccinated_single', 'vaccinated_single_per_100_inhabitants']

print(covid_df.head)

def getAllRegionsCovid(regions_list=regions_list_BR, country="Brazil"):
    regions_dict = {}

#     print(regions_list)
    for r in regions_list:
        sub_df = covid_df[(covid_df['state']== 'SP')]
        sub_df.loc[:,'date'] = pd.to_datetime(sub_df.loc[:,'date'])
        sub_df = sub_df.sort_values('date', ascending=True)
        regions_dict[r]=sub_df
#     print(regions_dict)
    return regions_dict
# Out:
# <bound method NDFrame.head of        epi_week        date country  state   city  newDeaths  deaths  \
# 0             9  2020-02-25  Brazil     SP  TOTAL          0       0
# 1             9  2020-02-25  Brazil  TOTAL  TOTAL          0       0
# 2             9  2020-02-26  Brazil     SP  TOTAL          0       0
# 3             9  2020-02-26  Brazil  TOTAL  TOTAL          0       0
# 4             9  2020-02-27  Brazil     SP  TOTAL          0       0
# ...         ...         ...     ...    ...    ...        ...     ...
# 13673       128  2021-07-13  Brazil     SC  TOTAL         54   17410
# 13674       128  2021-07-13  Brazil     SE  TOTAL          9    5829
# 13675       128  2021-07-13  Brazil     SP  TOTAL        640  132845
# 13676       128  2021-07-13  Brazil     TO  TOTAL          0    3354
# 13677       128  2021-07-13  Brazil  TOTAL  TOTAL       1580  536129
#
#        newCases  totalCases  deathsMS  ...   recovered   suspects       tests  \
# 0             1           1         0  ...         NaN        NaN         NaN
# 1             1           1         0  ...         NaN        NaN         NaN
# 2             0           1         0  ...         NaN        NaN         NaN
# 3             0           1         0  ...         NaN        NaN         NaN
# 4             0           1         0  ...         NaN        NaN         NaN
# ...         ...         ...       ...  ...         ...        ...         ...
# 13673      2477     1081566     17410  ...   1042555.0   173986.0   2320266.0
# 13674       120      269198      5829  ...    251350.0      728.0    542553.0
# 13675     10546     3879846    132845  ...   3478678.0  1142684.0  14183490.0
# 13676         0      203024      3354  ...    185493.0      441.0    600910.0
# 13677     45573    19159197    535838  ...  17035888.0  7614414.0  54522599.0
#
#        tests_per_100k_inhabitants  vaccinated  vaccinated_per_100_inhabitants  \
# 0                             NaN         NaN                             NaN
# 1                             NaN         NaN                             NaN
# 2                             NaN         NaN                             NaN
# 3                             NaN         NaN                             NaN
# 4                             NaN         NaN                             NaN
# ...                           ...         ...                             ...
# 13673                 32384.29385   3104097.0                        43.32434
# 13674                 23602.64254    903290.0                        39.29576
# 13675                 30888.03080  21900107.0                        47.69286
# 13676                 38204.78032    525947.0                        33.43877
# 13677                 25747.87883  85574158.0                        40.41174
#
#        vaccinated_second  vaccinated_second_per_100_inhabitants  \
# 0                    NaN                                    NaN
# 1                    NaN                                    NaN
# 2                    NaN                                    NaN
# 3                    NaN                                    NaN
# 4                    NaN                                    NaN
# ...                  ...                                    ...
# 13673          1042640.0                               14.55228
# 13674           285196.0                               12.40686
# 13675          6638619.0                               14.45722
# 13676           159153.0                               10.11866
# 13677         28763435.0                               13.58331
#
#        vaccinated_single  vaccinated_single_per_100_inhabitants
# 0                    NaN                                    NaN
# 1                    NaN                                    NaN
# 2                    NaN                                    NaN
# 3                    NaN                                    NaN
# 4                    NaN                                    NaN
# ...                  ...                                    ...
# 13673                NaN                                    NaN
# 13674            34366.0                                1.49502
# 13675           850652.0                                1.85250
# 13676            17314.0                                1.10079
# 13677          2798661.0                                1.32165
#
# [13678 rows x 24 columns]>

# %%
sp_covid = getAllRegionsCovid(['State of São Paulo'])
newCases = sp_covid['State of São Paulo']['newCases'].values
covid_dates = sp_covid['State of São Paulo']['date'].values

mob_df = getAllRegionsGroups(regions_list=['State of São Paulo'])['State of São Paulo']
mob_dates = mob_df['date'].values
mob_dates -= np.timedelta64(7,'D') # com offset de 7 dias
newCases_norm = newCases/np.max(newCases)

scaler = MinMaxScaler(feature_range=(-1,1))
mobility_norm = scaler.fit_transform(mob_df[categories_google_mobility].values)

# %%
i = 0
for group in categories_google_mobility:
    print(group)
    group_values = mobility_norm[:,i]
    fig, ax = plt.subplots(figsize=(8, 4))
    plt.plot(covid_dates[:], newCases_norm[:], label="new_cases")
    plt.plot(mob_dates[:], group_values[:], label=group)
   
    plt.legend(loc='best') 
    plt.grid()
    plt.show()
    
    i+=1
# Out:
# retail_and_recreation_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="800">
# grocery_and_pharmacy_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="800">
# parks_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="800">
# transit_stations_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="800">
# workplaces_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="800">
# residential_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="800">

# %%
i = 0
for group in categories_google_mobility:
    print(group)
    group_values = mobility_norm[:,i]
    fig, ax = plt.subplots(figsize=(16, 4))
    plt.scatter(group_values[-460:], newCases_norm[-470:-10], label=group) #com offset de 7 dias
#     plt.scatter(group_values[-460:], newCases_norm[-463:-3], label=group) #sem offset de 7 dias 
   
    plt.legend(loc='best') 
    plt.grid()
    plt.show()
    
    i+=1
# Out:
# retail_and_recreation_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="1600">
# grocery_and_pharmacy_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="1600">
# parks_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="1600">
# transit_stations_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="1600">
# workplaces_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="1600">
# residential_percent_change_from_baseline
# <img src="data:image/png;base64,..." width="1600">
