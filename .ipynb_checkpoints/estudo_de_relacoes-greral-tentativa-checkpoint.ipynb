# %%
'''
    Titulo: Como a mobilidade urbana se relaciona com o aumento de numero de casos de covid.


'''


import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %matplotlib notebook

# %%
# path = os.path.dirname(os.path.abspath(__file__))


'''
    Peguei essa primeira parte desse site: https://www.viralml.com/video-content.html?v=A6nWZKZpL3k
'''
# Se demorar mto pra carregar o csv, baixa o csv e descomenta essa linha (ps: ta com o \\ do windows)
# gmr_df = pd.read_csv(path+'\\Global_Mobility_Report.csv')  
gmr_df = pd.read_csv('https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv')
gmr_df.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#   metro_area iso_3166_2_code  census_fips_code                     place_id  \
# 0        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 1        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 2        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 3        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 4        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# 0  2020-02-15                                                0.0
# 1  2020-02-16                                                1.0
# 2  2020-02-17                                               -1.0
# 3  2020-02-18                                               -2.0
# 4  2020-02-19                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
# 3                                                1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
# 3                                 5.0
# 4                                 4.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            0.0
# 1                                            1.0
# 2                                            1.0
# 3                                            0.0
# 4                                           -1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      2.0
# 2                                      2.0
# 3                                      2.0
# 4                                      2.0
#
#    residential_percent_change_from_baseline
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0

# %%
# Categories available
categories_google_mobility = ['retail_and_recreation_percent_change_from_baseline',
 'grocery_and_pharmacy_percent_change_from_baseline',
 'parks_percent_change_from_baseline',
 'transit_stations_percent_change_from_baseline',
 'workplaces_percent_change_from_baseline',
 'residential_percent_change_from_baseline']
categories_google_mobility

regions_list_BR = [ 'Federal District', 'State of Acre','State of Alagoas','State of Amapá', 'State of Amazonas', 
                    'State of Bahia', 'State of Ceará', 'State of Espírito Santo', 'State of Goiás',
                    'State of Maranhão', 'State of Mato Grosso', 'State of Mato Grosso do Sul', 'State of Minas Gerais',
                    'State of Pará', 'State of Paraíba', 'State of Paraná', 'State of Pernambuco', 'State of Piauí', 
                    'State of Rio de Janeiro', 'State of Rio Grande do Norte',
                    'State of Rio Grande do Sul', 'State of Rondônia', 'State of Roraima', 'State of Santa Catarina', 
                    'State of São Paulo', 'State of Sergipe', 'State of Tocantins'
                  ]

regions_abbr_BR = [ 'DF','AC','AL','AP','AM','BA','CE','ES','GO','MA','MT','MS','MG','PA',
                    'PB','PR','PE','PI','RJ','RN','RS','RO','RR','SC','SP','SE','TO']

# %%
def getAllRegionsGroups(regions_list=regions_list_BR, country="Brazil"):
    regions_dict = {}
#     print(regions_list)
    for r in regions_list:
        sub_df = gmr_df[(gmr_df['country_region']== country) & (gmr_df['sub_region_1']==r) & (pd.isnull(gmr_df['sub_region_2']))]
        sub_df.loc[:,'date'] = pd.to_datetime(sub_df.loc[:,'date'])
        sub_df = sub_df.sort_values('date', ascending=True)
        regions_dict[r]=sub_df
#     print(regions_dict)
    return regions_dict


def plotGroups(sub_df, region, country="Brazil"):
    # let's plot all time series for this region
    for group in categories_google_mobility:
#         print(group)
        
        fig, ax = plt.subplots(figsize=(16, 4))
        plt.plot(sub_df['date'], sub_df[group], label=group)
        ax.axhline(y=0, color='gray')
        ax.axvline(pd.to_datetime('2020-03-10'), color='r', linestyle='--', lw=2)
        plt.title(country + ' '+ region + ': ' + group)
        plt.legend(loc='best') 
        plt.grid()
        plt.show()
        # plt.savefig(fname=path+'\\'+group+'.png', format='png')


# - - - - - - - -  TESTE - - - - - - - -  
# sdf = getAllRegionsGroups(regions_list=['State of São Paulo'])   #, 'State of Rio de Janeiro'
# print(sdf)
# plotGroups(sdf['State of São Paulo'], 'State of São Paulo')
# plotGroups(sdf['State of Rio de Janeiro'], 'State of RIO')

# %%
# - - - - - - - -  CASOS DE COVID - - - - - - - -  
covid_df = pd.read_csv('https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv')
col = [ 'epi_week', 'date', 'country', 'state', 'city', 'newDeaths', 'deaths', 'newCases', 'totalCases', 
        'deathsMS', 'totalCasesMS', 'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants', 
        'deaths_by_totalCases', 
        'recovered', 'suspects', 'tests', 'tests_per_100k_inhabitants', 'vaccinated', 
        'vaccinated_per_100_inhabitants', 'vaccinated_second', 
        'vaccinated_second_per_100_inhabitants', 'vaccinated_single', 'vaccinated_single_per_100_inhabitants']

print(covid_df.head)

def getAllRegionsCovid(regions_list=regions_list_BR, regions_abbr=regions_abbr_BR,
                       country="Brazil"):
    regions_dict = {}
    
#     print(regions_list)
    for r in range(len(regions_list)):
        sub_df = covid_df[(covid_df['state']== regions_abbr[r])]
        sub_df.loc[:,'date'] = pd.to_datetime(sub_df.loc[:,'date'])
        sub_df = sub_df.sort_values('date', ascending=True)
        regions_dict[regions_list[r]]=sub_df
#     print(regions_dict)
    return regions_dict
# Out:
# <bound method NDFrame.head of        epi_week        date country  state   city  newDeaths  deaths  \
# 0             9  2020-02-25  Brazil     SP  TOTAL          0       0
# 1             9  2020-02-25  Brazil  TOTAL  TOTAL          0       0
# 2             9  2020-02-26  Brazil     SP  TOTAL          0       0
# 3             9  2020-02-26  Brazil  TOTAL  TOTAL          0       0
# 4             9  2020-02-27  Brazil     SP  TOTAL          0       0
# ...         ...         ...     ...    ...    ...        ...     ...
# 13757       128  2021-07-16  Brazil     SC  TOTAL         46   17520
# 13758       128  2021-07-16  Brazil     SE  TOTAL          7    5853
# 13759       128  2021-07-16  Brazil     SP  TOTAL        419  134320
# 13760       128  2021-07-16  Brazil     TO  TOTAL          0    3386
# 13761       128  2021-07-16  Brazil  TOTAL  TOTAL       1377  540683
#
#        newCases  totalCases  deathsMS  ...   recovered   suspects       tests  \
# 0             1           1         0  ...         NaN        NaN         NaN
# 1             1           1         0  ...         NaN        NaN         NaN
# 2             0           1         0  ...         NaN        NaN         NaN
# 3             0           1         0  ...         NaN        NaN         NaN
# 4             0           1         0  ...         NaN        NaN         NaN
# ...         ...         ...       ...  ...         ...        ...         ...
# 13757      2152     1088880     17520  ...   1053386.0   173986.0   2320266.0
# 13758       395      270472      5853  ...    256875.0      728.0    558020.0
# 13759     11475     3919754    134320  ...   3566058.0  1142684.0  14183490.0
# 13760         0      204350      3386  ...    187069.0      441.0    606754.0
# 13761     42277    19313183    540398  ...  17252650.0  7614414.0  54673618.0
#
#        tests_per_100k_inhabitants  vaccinated  vaccinated_per_100_inhabitants  \
# 0                             NaN         NaN                             NaN
# 1                             NaN         NaN                             NaN
# 2                             NaN         NaN                             NaN
# 3                             NaN         NaN                             NaN
# 4                             NaN         NaN                             NaN
# ...                           ...         ...                             ...
# 13757                 32384.29385   3195436.0                        44.59917
# 13758                 24275.50228    909356.0                        39.55965
# 13759                 30888.03080  22750249.0                        49.54425
# 13760                 38576.33136    547464.0                        34.80678
# 13761                 25819.19640  88183910.0                        41.64417
#
#        vaccinated_second  vaccinated_second_per_100_inhabitants  \
# 0                    NaN                                    NaN
# 1                    NaN                                    NaN
# 2                    NaN                                    NaN
# 3                    NaN                                    NaN
# 4                    NaN                                    NaN
# ...                  ...                                    ...
# 13757           945423.0                               13.19541
# 13758           285196.0                               12.40686
# 13759          7138690.0                               15.54625
# 13760           165250.0                               10.50630
# 13761         29911747.0                               14.12559
#
#        vaccinated_single  vaccinated_single_per_100_inhabitants
# 0                    NaN                                    NaN
# 1                    NaN                                    NaN
# 2                    NaN                                    NaN
# 3                    NaN                                    NaN
# 4                    NaN                                    NaN
# ...                  ...                                    ...
# 13757           166257.0                                2.32047
# 13758            38692.0                                1.68322
# 13759           964858.0                                2.10122
# 13760            21773.0                                1.38429
# 13761          3555576.0                                1.67909
#
# [13762 rows x 24 columns]>

# %%
# regions_selected = [regions_list_BR[i] for i in [24,25,26]]
# regions_selected_abbr = [regions_abbr_BR[i] for i in [24,25,26]]

# print(regions_selected_abbr)

# cases_df = getAllRegionsCovid()
# mob_df = getAllRegionsGroups()

# print(cases_df)

# %%
def getData():
    cases_df = getAllRegionsCovid(regions_list_BR[:10],regions_abbr_BR[:10])
    mob_df = getAllRegionsGroups(regions_list_BR[:10])
    
    mobility_all = []
    cases_all = []
    mobility_dates = []
    cases_dates = []
    
    for r in regions_list_BR[:10]:
        newCases = cases_df[r]['newCases'].values
        newCases_norm = newCases/np.max(newCases)
        scaler = MinMaxScaler(feature_range=(-1,1))        
        mobility_norm = scaler.fit_transform(mob_df[r][categories_google_mobility].values)
        
        covid_dates = cases_df[r]['date'].values
        
        mob_dates = mob_df[r]['date'].values
        mob_dates += np.timedelta64(7,'D') # com offset de 7 dias

        for i in range(len(newCases_norm)):
            cases_all.append(newCases_norm[i]) 
            cases_dates.append(covid_dates[i]) 
        for i in range(len(mobility_norm)):
            mobility_all.append(mobility_norm[i])
            mobility_dates.append(mob_dates[i])

    Y_data = (np.array([cases_all]).T)
    X_data = np.array(mobility_all)    
    
    
    return X_data, Y_data, mobility_dates, cases_dates


X_data, Y_data, mobility_dates, cases_dates = getData()

print(X_data.shape)
print(Y_data.shape)
# Out:
# (5150, 6)
# (4915, 1)

# %%
i = 0

for group in categories_google_mobility:
    print(group)
    group_values = X_data[:,i]
    fig, ax = plt.subplots(figsize=(8, 4))
    plt.plot(cases_dates[:], Y_data[:], label="new_cases")
    plt.plot(mobility_dates[:], group_values[:], label=group)
   
    plt.legend(loc='best') 
    plt.grid()
    plt.show()
    
    i+=1
# Out:
# retail_and_recreation_percent_change_from_baseline
# grocery_and_pharmacy_percent_change_from_baseline
# parks_percent_change_from_baseline
# transit_stations_percent_change_from_baseline
# workplaces_percent_change_from_baseline
# residential_percent_change_from_baseline

# %%
print(cases_dates[0]+np.timedelta64(12,'W'))
print(len(cases_dates))
print(mobility_dates[14],cases_dates[1])

def getCorrespondentData(X_data,Y_data, mobility_dates,cases_dates):
    i = 0
    j = 0
    X_filter = []
    Y_filter = []
    while (i < len(mobility_dates)) and (j < len(cases_dates)):
#         print(mobility_dates[i]," - ", cases_dates[j])
        if mobility_dates[i] == cases_dates[j]:
            X_filter.append(X_data[i])
            Y_filter.append(Y_data[j])
            i+=1
            j+=1
        elif (mobility_dates[i] < cases_dates[j]) or mobility_dates[i] > (cases_dates[j] + np.timedelta64(30,'W')):
            i += 1
        elif mobility_dates[i] > cases_dates[j]:
            j += 1
             
    return np.array(X_filter), np.array(Y_filter)
# Out:
# 2020-05-30T00:00:00.000000000
# 4915
# 2020-03-07T00:00:00.000000000 2020-03-08T00:00:00.000000000

# %%
X_filter, Y_filter = getCorrespondentData(X_data,Y_data, mobility_dates,cases_dates)
print(X_filter.shape)
print(Y_filter.shape)

i = 0

for group in categories_google_mobility:
    print(group)
    group_values = X_filter[:,i]
    fig, ax = plt.subplots(figsize=(16, 4))
    plt.scatter(group_values[:], Y_filter[:], label=group) #com offset de 7 dias
#     plt.scatter(group_values[-460:], newCases_norm[-463:-3], label=group) #sem offset de 7 dias 
   
    plt.legend(loc='best') 
    plt.grid()
    plt.show()
    
    i+=1
# Out:
# (4915, 6)
# (4915, 1)
# retail_and_recreation_percent_change_from_baseline
# grocery_and_pharmacy_percent_change_from_baseline
# parks_percent_change_from_baseline
# transit_stations_percent_change_from_baseline
# workplaces_percent_change_from_baseline
# residential_percent_change_from_baseline

# %%
from keras.models import Sequential
from keras.layers import Dense

X_train = X_filter[:6500]
Y_train = Y_filter[:6500]
X_test = X_filter[6500:]
Y_test = Y_filter[6500:]
# X = mobility_norm[-460:,:]
# Y = newCases_norm[-470:-10]
# Y = Y.reshape((len(Y),1))

print("Mobility Features")
print(X_train[:5])
print("X shape: ",X_train.shape)


print("Covid Cases")
print(Y_train[:5])
print("Y shape: ",Y_train.shape)
# Out:
# Mobility Features
# [[ 0.6344086   0.0483871  -0.35403727  0.45679012  0.56190476 -0.5       ]
#  [ 0.6344086   0.16129032 -0.36645963  0.48148148  0.46666667 -0.4375    ]
#  [ 0.5483871  -0.0483871  -0.22981366  0.80246914  0.86666667 -0.8125    ]
#  [ 0.69892473  0.11290323 -0.04347826  0.85185185  0.86666667 -0.875     ]
#  [ 0.65591398  0.08064516 -0.0310559   0.82716049  0.86666667 -0.875     ]]
# X shape:  (4915, 6)
# Covid Cases
# [[0.00031536]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.00031536]]
# Y shape:  (4915, 1)

# %%
model = Sequential()
model.add(Dense(6, input_dim=6, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=700, batch_size=1008)
# Out:
# Epoch 1/700
# 5/5 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 2/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0202
# Epoch 3/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0162
# Epoch 4/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 5/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 6/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 7/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 8/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 9/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 10/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 11/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0187
# Epoch 12/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 13/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 14/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 15/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 16/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 17/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0177
# Epoch 18/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 19/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 20/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0187
# Epoch 21/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0205
# Epoch 22/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 23/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0161
# Epoch 24/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0197
# Epoch 25/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 26/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0177
# Epoch 27/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0167
# Epoch 28/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 29/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0167
# Epoch 30/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 31/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 32/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 33/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 34/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 35/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 36/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 37/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 38/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 39/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0163
# Epoch 40/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0197
# Epoch 41/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0178
# Epoch 42/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 43/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 44/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 45/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 46/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 47/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0175
# Epoch 48/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 49/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 50/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 51/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 52/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 53/700
# 5/5 [==============================] - 0s 998us/step - loss: nan - accuracy: 0.0197
# Epoch 54/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 55/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 56/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0200
# Epoch 57/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0192
# Epoch 58/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 59/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0212
# Epoch 60/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0169
# Epoch 61/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 62/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 63/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 64/700
# 5/5 [==============================] - 0s 998us/step - loss: nan - accuracy: 0.0167
# Epoch 65/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0188
# Epoch 66/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0188
# Epoch 67/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0160
# Epoch 68/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0208
# Epoch 69/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0166
# Epoch 70/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0189
# Epoch 71/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0163
# Epoch 72/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 73/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 74/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 75/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 76/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 77/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 78/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 79/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0163
# Epoch 80/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 81/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 82/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 83/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 84/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0157
# Epoch 85/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0177
# Epoch 86/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0204
# Epoch 87/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 88/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 89/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 90/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0213
# Epoch 91/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 92/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 93/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 94/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 95/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0207
# Epoch 96/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 97/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 98/700
# 5/5 [==============================] - 0s 998us/step - loss: nan - accuracy: 0.0188
# Epoch 99/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0167
# Epoch 100/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 101/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 102/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 103/700
# 5/5 [==============================] - 0s 982us/step - loss: nan - accuracy: 0.0188
# Epoch 104/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 105/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0194
# Epoch 106/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0192
# Epoch 107/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0195
# Epoch 108/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 109/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 110/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 111/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 112/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0183
# Epoch 113/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 114/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 115/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 116/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 117/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0200
# Epoch 118/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0200
# Epoch 119/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 120/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 121/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 122/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 123/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0202
# Epoch 124/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 125/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 126/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 127/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0177
# Epoch 128/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 129/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 130/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0162
# Epoch 131/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0167
# Epoch 132/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 133/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 134/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 135/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 136/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 137/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 138/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 139/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 140/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 141/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 142/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 143/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0207
# Epoch 144/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 145/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 146/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 147/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0172
# Epoch 148/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 149/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 150/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 151/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0206
# Epoch 152/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0161
# Epoch 153/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0207
# Epoch 154/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0206
# Epoch 155/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 156/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0177
# Epoch 157/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0197
# Epoch 158/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 159/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 160/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 161/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 162/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 163/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0200
# Epoch 164/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0176
# Epoch 165/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 166/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0184
# Epoch 167/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 168/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 169/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0205
# Epoch 170/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0177
# Epoch 171/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0201
# Epoch 172/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0201
# Epoch 173/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 174/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0200
# Epoch 175/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0171
# Epoch 176/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 177/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 178/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 179/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 180/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 181/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 182/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0157
# Epoch 183/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 184/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 185/700
# 5/5 [==============================] - 0s 998us/step - loss: nan - accuracy: 0.0193
# Epoch 186/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0203
# Epoch 187/700
# 5/5 [==============================] - 0s 998us/step - loss: nan - accuracy: 0.0183
# Epoch 188/700
# 5/5 [==============================] - 0s 998us/step - loss: nan - accuracy: 0.0183
# Epoch 189/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 190/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0178
# Epoch 191/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 192/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 193/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0184
# Epoch 194/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 195/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 196/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 197/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0159
# Epoch 198/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 199/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0176
# Epoch 200/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 201/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 202/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0197
# Epoch 203/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 204/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0167
# Epoch 205/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0169
# Epoch 206/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0188
# Epoch 207/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 208/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 209/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 210/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 211/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 212/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 213/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 214/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 215/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 216/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 217/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0173
# Epoch 218/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 219/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 220/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0184
# Epoch 221/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 222/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 223/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 224/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 225/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0213
# Epoch 226/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 227/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 228/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0172
# Epoch 229/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0170
# Epoch 230/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 231/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 232/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 233/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 234/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0188
# Epoch 235/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 236/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 237/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 238/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0189
# Epoch 239/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0214
# Epoch 240/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 241/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 242/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 243/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0177
# Epoch 244/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 245/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0167
# Epoch 246/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 247/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 248/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 249/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 250/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 251/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0193
# Epoch 252/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0179
# Epoch 253/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0205
# Epoch 254/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 255/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0184
# Epoch 256/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 257/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 258/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 259/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0167
# Epoch 260/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0205
# Epoch 261/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0166
# Epoch 262/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 263/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0220
# Epoch 264/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 265/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 266/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0206
# Epoch 267/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 268/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0202
# Epoch 269/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 270/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 271/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0192
# Epoch 272/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 273/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 274/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 275/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 276/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0185
# Epoch 277/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 278/700
# 5/5 [==============================] - 0s 966us/step - loss: nan - accuracy: 0.0188
# Epoch 279/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 280/700
# 5/5 [==============================] - 0s 959us/step - loss: nan - accuracy: 0.0182
# Epoch 281/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 282/700
# 5/5 [==============================] - 0s 888us/step - loss: nan - accuracy: 0.0177
# Epoch 283/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 284/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 285/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 286/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 287/700
# 5/5 [==============================] - 0s 989us/step - loss: nan - accuracy: 0.0192
# Epoch 288/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0179
# Epoch 289/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 290/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 291/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 292/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0208
# Epoch 293/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 294/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 295/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 296/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 297/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0186
# Epoch 298/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0171
# Epoch 299/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 300/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 301/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0192
# Epoch 302/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0183
# Epoch 303/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 304/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0188
# Epoch 305/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 306/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 307/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 308/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0187
# Epoch 309/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0188
# Epoch 310/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 311/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 312/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0173
# Epoch 313/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 314/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0169
# Epoch 315/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 316/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 317/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 318/700
# 5/5 [==============================] - ETA: 0s - loss: nan - accuracy: 0.018 - 0s 997us/step - loss: nan - accuracy: 0.0181
# Epoch 319/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 320/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 321/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 322/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0180
# Epoch 323/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0159
# Epoch 324/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0182
# Epoch 325/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 326/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 327/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 328/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 329/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0203
# Epoch 330/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 331/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0184
# Epoch 332/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0200
# Epoch 333/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0177
# Epoch 334/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 335/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 336/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 337/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 338/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 339/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0188
# Epoch 340/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0195
# Epoch 341/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 342/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 343/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0202
# Epoch 344/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 345/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 346/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 347/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 348/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0191
# Epoch 349/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 350/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0178
# Epoch 351/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 352/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 353/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 354/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0173
# Epoch 355/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 356/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 357/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 358/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 359/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0178
# Epoch 360/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0178
# Epoch 361/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 362/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 363/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0183
# Epoch 364/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 365/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 366/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 367/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0172
# Epoch 368/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0188
# Epoch 369/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0180
# Epoch 370/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 371/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0185
# Epoch 372/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0201
# Epoch 373/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0209
# Epoch 374/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0183
# Epoch 375/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 376/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 377/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0171
# Epoch 378/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0175
# Epoch 379/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0188
# Epoch 380/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0169
# Epoch 381/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 382/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0181
# Epoch 383/700
# 5/5 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0212
# Epoch 384/700
# 5/5 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0184
# Epoch 385/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0198
# Epoch 386/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 387/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 388/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 389/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 390/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0199
# Epoch 391/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0219
# Epoch 392/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 393/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0173
# Epoch 394/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0167
# Epoch 395/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 396/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 397/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 398/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 399/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0186
# Epoch 400/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 401/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0197
# Epoch 402/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0189
# Epoch 403/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 404/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0189
# Epoch 405/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0173
# Epoch 406/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0172
# Epoch 407/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0182
# Epoch 408/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0185
# Epoch 409/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0182
# Epoch 410/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 411/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 412/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0170
# Epoch 413/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 414/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0200
# Epoch 415/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 416/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0190
# Epoch 417/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0186
# Epoch 418/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 419/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0179
# Epoch 420/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0174
# Epoch 421/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0195
# Epoch 422/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 423/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0184
# Epoch 424/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0181
# Epoch 425/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0177
# Epoch 426/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0180
# Epoch 427/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0201
# Epoch 428/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 429/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0188
# Epoch 430/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0181
# Epoch 431/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 432/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0200
# Epoch 433/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 434/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0172
# Epoch 435/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 436/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0168
# Epoch 437/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0176
# Epoch 438/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0182
# Epoch 439/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0191
# Epoch 440/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0162
# Epoch 441/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0187
# Epoch 442/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0204
# Epoch 443/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0205
# Epoch 444/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 445/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 446/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0187
# Epoch 447/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 448/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 449/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 450/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0210
# Epoch 451/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0194
# Epoch 452/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 453/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 454/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0193
# Epoch 455/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0174
# Epoch 456/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0175
# Epoch 457/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0208
# Epoch 458/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 459/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0189
# Epoch 460/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0184
# Epoch 461/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0191
# Epoch 462/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0186
# Epoch 463/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0192
# Epoch 464/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0178
# Epoch 465/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 466/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 467/700
# 5/5 [==============================] - 0s 997us/step - loss: nan - accuracy: 0.0189
# Epoch 468/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0203
# Epoch 469/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0198
# Epoch 470/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0196
# Epoch 471/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0183
# Epoch 472/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0175
# Epoch 473/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0192
# Epoch 474/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0188
# Epoch 475/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0173
# Epoch 476/700
# 5/5 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0178
# Epoch 477/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0176
# Epoch 478/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0195
# Epoch 479/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0201
# Epoch 480/700
# 5/5 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.0190
# Epoch 481/700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\TIEFIG~1\AppData\Local\Temp/ipykernel_16912/1828799571.py in <module>
#       1 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#       2
# ----> 3 model.fit(X_train, Y_train, epochs=700, batch_size=1008)
#       4
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1161               logs = tmp_logs  # No error, now safe to assign to logs.
#    1162               end_step = step + data_handler.step_increment
# -> 1163               callbacks.on_train_batch_end(end_step, logs)
#    1164               if self.stop_training:
#    1165                 break
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     276       self._call_batch_begin_hook(mode, batch, logs)
#     277     elif hook == 'end':
# --> 278       self._call_batch_end_hook(mode, batch, logs)
#     279     else:
#     280       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     296       self._batch_times.append(batch_time)
#     297
# --> 298     self._call_batch_hook_helper(hook_name, batch, logs)
#     299
#     300     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     336       hook = getattr(callback, hook_name)
#     337       if getattr(callback, '_supports_tf_logs', False):
# --> 338         hook(batch, logs)
#     339       else:
#     340         if numpy_logs is None:  # Only convert once.
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1042
#    1043   def on_train_batch_end(self, batch, logs=None):
# -> 1044     self._batch_update_progbar(batch, logs)
#    1045
#    1046   def on_test_batch_end(self, batch, logs=None):
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1107       # Only block async when verbose = 1.
#    1108       logs = tf_utils.sync_to_numpy_or_python_type(logs)
# -> 1109       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1110
#    1111   def _finalize_progbar(self, logs, counter):
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\keras\utils\generic_utils.py in update(self, current, values, finalize)
#     901       prev_total_width = self._total_width
#     902       if self._dynamic_display:
# --> 903         sys.stdout.write('\b' * prev_total_width)
#     904         sys.stdout.write('\r')
#     905       else:
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     517             is_child = (not self._is_master_process())
#     518             # only touch the buffer in the IO thread to avoid races
# --> 519             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     520             if is_child:
#     521                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\users\tiefighter8100\appdata\local\programs\python\python38\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
model.output_shape
print(max(X_train[:,2]))
print(mobility_dates[3944])
# Out:
# 1.0
# 2021-01-26T00:00:00.000000000

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X_train, Y_train)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 204/204 [==============================] - 0s 564us/step - loss: nan - accuracy: 0.0168
# Accuracy: 1.68

# %%
# newCases = cases_df[regions_selected[2]]['newCases'].values
# newCases_norm = newCases/np.max(newCases)
# mobility_norm = scaler.fit_transform(mob_df[regions_selected[2]][categories_google_mobility].values)

# %%
# X_test = mobility_norm[-460:,:]
# Y_test = newCases_norm[-470:-10]
# Y_test = Y_test.reshape((len(Y_test),1))

print("MobilitY_test Features")
print(X_test[:5])
print("X_test shape: ",X_test.shape)


print("Covid Cases")
print(Y_test[:5])
print("Y_test shape: ",Y_test.shape)

_, accuracY_test = model.evaluate(X_test, Y_test)
print('AccuracY_test: %.2f' % (accuracY_test*100))
# Out:
# MobilitY_test Features
# [[-0.05555556  0.01315789 -0.17880795 -0.10447761  0.32673267 -0.28571429]
#  [-0.22222222 -0.10526316 -0.27152318 -0.34328358  0.42574257 -0.35714286]
#  [ 0.12962963 -0.01315789 -0.09933775 -0.07462687  0.12871287 -0.14285714]
#  [ 0.14814815  0.03947368 -0.16556291 -0.05970149  0.06930693 -0.21428571]
#  [ 0.12962963 -0.02631579 -0.09933775 -0.05970149  0.08910891 -0.21428571]]
# X_test shape:  (6754, 6)
# Covid Cases
# [[0.17779804]
#  [0.18121723]
#  [0.46979713]
#  [0.51607021]
#  [0.50262138]]
# Y_test shape:  (6754, 1)
# 212/212 [==============================] - 0s 489us/step - loss: nan - accuracy: 0.0262
# AccuracY_test: 2.62

# %%
predict = model.predict(X_test)
# plt.plot(Y_test)
plt.plot(predict)
plt.show()
